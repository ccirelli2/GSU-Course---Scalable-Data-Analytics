# %%
import os
import pandas as pd

# %%
'''The purpose of this code is to merge the placing broker from the Salesforce Dataset to the DB Data set using the submission number. 

Then to merge the broker name to the Master File using the Company First, Second name and City Combo'''

# %%
df_DB = pd.read_csv(r'C:\Users\Chris.Cirelli\Desktop\Capital IQ Match w Salesforce\Final Report\D&B Universe.csv')

# %%
df_SF = pd.read_csv(r'C:\Users\Chris.Cirelli\Desktop\Capital IQ Match w Salesforce\Data Files\Salesforce Universe List.csv')

# %%
df_DB.head(2)
# Out:
#              Primary Business Name Billing Zip/Postal Code Shipping City  \
# 0  Wilcox Truck Line, Incorporated                   65808   SPRINGFIELD
# 1               Valley Airways Inc                   69361   Scottsbluff
#
#              Client Name  Primary SIC Code Legal Structure  \
# 0  WILCOX TRUCK LINE INC              4213     Corporation
# 1   Valley Airways, Inc.              4522     Corporation
#
#             Primary SIC Description   D&B Company ID  D-U-N-S Number  \
# 0            Trucking, Except Local  06EE0000000EI0U         7452667
# 1  Air Transportation, Nonscheduled  06E0L000000AHG8        82726092
#
#           Delinquency Risk  Number of Employees - Total  Annual Sales Volume  \
# 0  Low risk of delinquency                          119             13688147
# 1  Low risk of delinquency                            6               555056
#
#         Submission Name
# 0  SD-TRP-ATL-16-638375
# 1  SAV-WC-ATL-16-791440

# %%
df_SF.head(2)
# Out:
#   100 Percent Policy Booked Premium Currency  \
# 0                                        USD
# 1                                        USD
#
#    100 Percent Policy Booked Premium Industry      Submission Name  \
# 0                                0.0   Retail    NY - 1109736 - 17
# 1                                NaN   Retail  SP-NY-031617-552673
#
#   Annual Revenue Currency  Annual Revenue Shipping Address Line 1  \
# 0                     USD    4.858730e+11           702 SW 8th St
# 1                     USD    4.858730e+11           702 SW 8th St
#
#   Billing Zip/Postal Code Billing State/Province Billing City  \
# 0              72716-6299                     AR  Bentonville
# 1              72716-6299                     AR  Bentonville
#
#                ...               Production Office             Profit Center  \
# 0              ...                        New York      Ocean Marine - 20460
# ...

# %%
df_SF.columns
# Out:
# Index(['100 Percent Policy Booked Premium Currency',
#        '100 Percent Policy Booked Premium', 'Industry', 'Submission Name',
#        'Annual Revenue Currency', 'Annual Revenue', 'Shipping Address Line 1',
#        'Billing Zip/Postal Code', 'Billing State/Province', 'Billing City',
#        'Client Ultimate Parent DUNS Number', 'Employees', 'Production Office',
#        'Profit Center', 'Client Name',
#        'Placing Broker Ultimate Parent Producer', 'Policy Effective Date',
#        'Stage', 'Expiring Carrier Premium Currency',
#        'Expiring Carrier Premium', 'First Bound Premium',
#        'Submission Comments'],
#       dtype='object')

# %%
DB_SUbl

# %%
Placing_broker = []
Production_office = []
Profit_center = []
Client_name = []

for row in df_DB.itertuples():
    Sub_name = row[-1]
    if Sub_name in Salesforce_Subname_list
# Out:
# SD-TRP-ATL-16-638375
# SAV-WC-ATL-16-791440
# SD-XSE-LA-15-509109
# SAV-GA-SCT-16-862197
# SAV-GA-ATL-18-1377544
# SAV-GA-SCT-16-838747
# SAV-GA-SCT-16-863045
# SD-XCC-PHL-15-493856
# SD-XSE-BOS-15-584697
# SD-CNP-BOS-18-1397610
# XNV-LA-9262011-214749
# SD-XFL-SF-13-287311
# nan
# SAV-SS-SCT-16-821183
# SAV-GA-SCT-16-945135
# CNP-PA-422013-371845
# SD-FNL-CHG-16-644224
# SD-EIL-NYC-15-592990
# FNL-NY-412013-371268
# NRG-HO-1192011-139165
# SAV-SS-SCT-17-1051965
# EXC-SF-172011-136144
# nan
# EXC-CH-162011-135812
# SD-XCC-SF-15-507936
# SD-GCE-CHG-14-383202
# SD-NRG-NYC-17-1101812
# EIL-NY-172013-344312
# SD-NRG-PHL-14-386694
# SD-EIL-LA-16-1028547
# AT - 247038
# SD-XRG-HOU-13-327825
# SF - 123294
# SD-XSE-PHL-15-485367
# SD-EIL-NYC-16-638079
# SP-B-215-454779
# CNP-NY-4162012-270374
# SD-GCS-PHL-16-667090
# SD-DBA-PHL-17-1277598
# SD-NRG-LA-13-268032
# SD-CNP-CHG-13-307278
# SD-NRG-LA-13-281563
# nan
# SD-XCC-ATL-16-670613
# CNP-CH-2112012-250459
# NRG-HO-10122012-321577
# ...
